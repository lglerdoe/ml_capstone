# %% [markdown]
# This project has two data files:
# 1. application record
# 2. credit record

# %%
# !pip3 install pandas
# !pip3 install matplotlib
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 31.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.9/930.9 KB 22.3 MB/s eta 0:00:00m eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 31.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 KB 10.1 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
application_record = pd.read_csv('./data/application_record 2.csv')
application_record.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %%
application_record.tail(100)
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 438457  6799400           M            N               Y             0
# 438458  6800639           M            Y               Y             2
# 438459  6800643           M            Y               Y             2
# 438460  6800898           F            N               N             0
# 438461  6800963           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
len(application_record)
# Out:
# 438557

# %%
occupation_type_df = application_record.OCCUPATION_TYPE
occupation_type_df.isnull().value_counts()
# Out:
# False    304354
# True     134203
# Name: OCCUPATION_TYPE, dtype: int64

# %%
application_record_clean = application_record.dropna()
len(application_record_clean)
# Out:
# 304354

# %%
application_record_clean.loc[application_record_clean['CODE_GENDER'] == 'M', 'CODE_GENDER'] = 1
application_record_clean.loc[application_record_clean['CODE_GENDER'] == 'F', 'CODE_GENDER'] = 0

# application_record_clean['FLAG_OWN_CAR'] = np.where(application_record_clean['FLAG_OWN_CAR'] == 'Y', 1, 0)
# application_record_clean['FLAG_OWN_REALTY'] = np.where(application_record_clean['FLAG_OWN_REALTY'] == 'Y', 1, 0)

# application_record_clean['FLAG_OWN_CAR'].replace(['Y', 'N'], [1, 0])
# application_record_clean['FLAG_OWN_REALTY'] = application_record['FLAG_OWN_REALTY'].replace(['Y', 'N'], [1, 0])

# %% [markdown]
# There are 304354 records without null value.

# %%
credit_record = pd.read_csv('./data/credit_record.csv')
credit_record.describe()
# Out:
#                  ID  MONTHS_BALANCE
# count  1.048575e+06    1.048575e+06
# mean   5.068286e+06   -1.913700e+01
# std    4.615058e+04    1.402350e+01
# min    5.001711e+06   -6.000000e+01
# 25%    5.023644e+06   -2.900000e+01
# 50%    5.062104e+06   -1.700000e+01
# 75%    5.113856e+06   -7.000000e+00
# max    5.150487e+06    0.000000e+00

# %%
credit_record.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   ID              1048575 non-null  int64
#  1   MONTHS_BALANCE  1048575 non-null  int64
#  2   STATUS          1048575 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 24.0+ MB

# %%
credit_record.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %%
credit_record_clean = credit_record.dropna()
len(credit_record_clean)
# Out:
# 1048575

# %% [markdown]
# All rows has values in credit_record tabel

# %%
record_merged = application_record_clean.merge(credit_record)

# %%
record_merged.head(100)
# Out:
#          ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0   5008806            0             0                0             0
# 1   5008806            0             0                0             0
# 2   5008806            0             0                0             0
# 3   5008806            0             0                0             0
# 4   5008806            0             0                0             0
# ..      ...          ...           ...              ...           ...
# 95  5008811            0             0                0             0
# 96  5008811            0             0                0             0
# 97  5008811            0             0                0             0
# 98  5008811            0             0                0             0
# 99  5008811            0             0                0             0
#
#     AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...
